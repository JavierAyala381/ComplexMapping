# %% [markdown]
# # Complex Mapping

# %%
# %matplotlib notebook
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.display import HTML
import numpy as np
import matplotlib.animation as animation
import matplotlib as mpl
import cmath
from ComplexPlane import ComplexPlane
from ComplexNumber import ComplexNumber as cn

# %%
# Define the domain of the complex Plain
x = np.linspace(-2, 2)
y = np.linspace(-2, 2)

# Define the Z complex Plane
zPlane = ComplexPlane("Z space", x, y)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
a_dom = np.linspace(0, 2*cmath.pi, 100)
def rot(range):
    dom = np.full(100, cn(0,1), dtype=cn)
    return cn.map(dom, lambda i, z: z.getRotation(range[i]))

image = rot(a_dom)
anim = zPlane.tracePointPath(image)
HTML(anim.to_html5_video())

plt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[12], line 8
#       6 image = rot(a_dom)
#       7 anim = zPlane.tracePointPath(image)
# ----> 8 HTML(anim.to_html5_video())
#      10 plt.show()
#
# File ~/anaconda3/envs/Math/lib/python3.12/site-packages/matplotlib/animation.py:1285, in Animation.to_html5_video(self, embed_limit)
#    1282 path = Path(tmpdir, "temp.m4v")
#    1283 # We create a writer manually so that we can get the
#    1284 # appropriate size for the tag
# -> 1285 Writer = writers[mpl.rcParams['animation.writer']]
#    1286 writer = Writer(codec='h264',
#    1287                 bitrate=mpl.rcParams['animation.bitrate'],
#    1288                 fps=1000. / self._interval)
#    1289 self.save(str(path), writer=writer)
#
# ...
